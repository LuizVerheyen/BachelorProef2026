# %%
import yfinance as yf;
import pandas as pd;
import datetime;

# %%
start_date = '2016-01-01'
end_date = datetime.date.today().strftime("%Y-%m-%d")

# %%
sp500 = yf.download(tickers="^GSPC", start=start_date)
sp500.head()
# Out:
# c:\Users\Luizv\Documents\HoGent\jaar3\BachelorProef\BachelorProef2026\venv\Lib\site-packages\yfinance\scrapers\history.py:144: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   end_dt = pd.Timestamp.utcnow().tz_convert(tz)
# c:\Users\Luizv\Documents\HoGent\jaar3\BachelorProef\BachelorProef2026\venv\Lib\site-packages\yfinance\scrapers\history.py:201: Pandas4Warning: Timestamp.utcnow is deprecated and will be removed in a future version. Use Timestamp.now('UTC') instead.
#   dt_now = pd.Timestamp.utcnow()
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2016-01-04  2012.660034  2038.199951  1989.680054  2038.199951  4304880000
# 2016-01-05  2016.709961  2021.939941  2004.170044  2013.780029  3706620000
# ...

# %%
sp500 = sp500.reset_index()

# %%
sp500.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2575 entries, 0 to 2574
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   (Date, )         2575 non-null   datetime64[s]
#  1   (Close, ^GSPC)   2575 non-null   float64
#  2   (High, ^GSPC)    2575 non-null   float64
#  3   (Low, ^GSPC)     2575 non-null   float64
#  4   (Open, ^GSPC)    2575 non-null   float64
#  5   (Volume, ^GSPC)  2575 non-null   int64
# dtypes: datetime64[s](1), float64(4), int64(1)
# memory usage: 120.8 KB

# %%
sp500.columns = ['Date', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
sp500['DateKey'] = sp500['Date'].astype(str).str.replace('-', '').astype(int)
sp500.drop(columns=['Date'], inplace=True)

# %%
import matplotlib.pyplot as plt

sp500[['Close', 'High', 'Low', 'Open']].plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
sp500.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2575 entries, 0 to 2574
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Close    2575 non-null   float64
#  1   High     2575 non-null   float64
#  2   Low      2575 non-null   float64
#  3   Open     2575 non-null   float64
#  4   Volume   2575 non-null   int64
#  5   DateKey  2575 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 120.8 KB

# %%
# sp500.to_csv("../../raw/sp500.csv")
