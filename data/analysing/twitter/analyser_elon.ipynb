# %%
import pandas as pd

# %%
df = pd.read_csv("../../raw/elonmusk_tweets_history.csv")
# Out:
# C:\Users\Luizv\AppData\Local\Temp\ipykernel_31420\843867509.py:1: DtypeWarning: Columns (0: isReply, 1: isPinned, 2: isRetweet, 3: isQuote, 4: isConversationControlled) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../../raw/elonmusk_tweets_history.csv")

# %%
resultaat = df[df["fullText"] != None]["fullText"].count()
resultaat
# Out:
# np.int64(55099)

# %%
df['fullText'].count()
# Out:
# np.int64(55099)

# %%
resultaat = df[df["fullText"] != None]["fullText"].count()
resultaat
# Out:
# np.int64(55099)

# %%
df['fullText'].dtype == 'float64'
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 55099 entries, 0 to 55098
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        55099 non-null  int64
#  1   url                       55099 non-null  str
#  2   twitterUrl                55099 non-null  str
#  3   fullText                  55099 non-null  str
#  4   retweetCount              55009 non-null  float64
#  5   replyCount                54297 non-null  float64
#  6   likeCount                 55009 non-null  float64
#  7   quoteCount                54271 non-null  float64
#  8   viewCount                 34455 non-null  float64
#  9   createdAt                 55099 non-null  str
#  10  bookmarkCount             54271 non-null  float64
#  11  isReply                   54271 non-null  object
#  12  inReplyToId               39497 non-null  float64
#  13  conversationId            54297 non-null  float64
# ...

# %%
for i in df.columns:
    if df[i].dtype == "float64":
        resultaat = df[df[i] > 0][i].count()
    else:
        resultaat = df[df[i] != None][i].count()
        
    print(f"{i}: {resultaat / len(df) * 100}% filled")
# Out:
# id: 100.0% filled
# url: 100.0% filled
# twitterUrl: 100.0% filled
# fullText: 100.0% filled
# retweetCount: 99.64972141055192% filled
# replyCount: 97.22136517904136% filled
# likeCount: 98.65696292128715% filled
# quoteCount: 95.84202980090383% filled
# viewCount: 62.53289533385361% filled
# createdAt: 100.0% filled
# bookmarkCount: 93.55705185212074% filled
# isReply: 98.49725040381858% filled
# inReplyToId: 71.68369661881341% filled
# conversationId: 98.54443819307065% filled
# inReplyToUserId: 71.72725457812301% filled
# inReplyToUsername: 71.72725457812301% filled
# isPinned: 98.49725040381858% filled
# isRetweet: 99.83665765258898% filled
# isQuote: 99.7894698633369% filled
# isConversationControlled: 98.49725040381858% filled
# possiblySensitive: 8.931196573440534% filled
# quoteId: 13.686273798072559% filled
# quote: 13.199876585781956% filled
# retweet: 1.9818871485870888% filled

# %%
df.drop(columns=['id', 'url', 'twitterUrl' ,'quoteId', 'quote', 'retweet', 'inReplyToUsername'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df = df.drop(columns=['id', 'url', 'twitterUrl' ,'quoteId', 'quote', 'retweet', 'inReplyToUsername'], inplace=True)
#
# File c:\Users\Luizv\Documents\HoGent\jaar3\BachelorProef\BachelorProef2026\venv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
# ...

# %%
df.head()
# Out:
#                                             fullText  retweetCount  \
# 0  RT @einarvollset: I read @paulg’s  “How to Mak...           NaN
# 1                            https://t.co/Zjn6r15lrR           NaN
# 2  RT @BillyM2k: dude bookmarks are an awesome tw...           NaN
# 3                         Event Horizon Balance Beam           NaN
# 4  RT @BillyM2k: @elonmusk oh that’s actually pre...           NaN
#
#    replyCount  likeCount  quoteCount  viewCount                  createdAt  \
# 0         NaN        NaN         NaN        NaN  2023-05-07 10:36:27+00:00
# 1         NaN        NaN         NaN        NaN  2023-05-13 05:48:56+00:00
# 2         NaN        NaN         NaN        NaN  2023-02-09 20:03:00+00:00
# 3         NaN        NaN         NaN        NaN  2023-05-12 05:52:26+00:00
# 4         NaN        NaN         NaN        NaN  2023-01-20 20:23:27+00:00
#
#    bookmarkCount isReply  inReplyToId  conversationId  inReplyToUserId  \
# ...
