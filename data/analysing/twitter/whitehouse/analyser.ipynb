# %%
import pandas as pd

# %%
df = pd.read_csv("../../../raw/tweets/WhiteHouse/WhiteHouse_tweets.csv")
df.head(10)
# Out:
#                   date    username  \
# 0  2026-03-21 18:57:57  WhiteHouse
# 1  2026-03-21 18:57:41  WhiteHouse
# 2  2026-03-21 17:52:23  WhiteHouse
# 3  2026-03-21 17:51:59  WhiteHouse
# 4  2026-03-21 17:17:42  WhiteHouse
# 5  2026-03-21 15:48:42  WhiteHouse
# 6  2026-03-20 22:39:45  WhiteHouse
# 7  2026-03-20 21:23:55  WhiteHouse
# 8  2026-03-20 21:14:32  WhiteHouse
# 9  2026-03-20 21:14:32  WhiteHouse
#
#                                                 text replies reposts  likes  \
# 0                                                NaN     156     255    907
# 1  The United States and Japan continued to stren...    1129    2992  13264
# 2                    NO MORE WAITING, NO MORE GAMES!   11063   11699  52704
# 3                    NO MORE WAITING, NO MORE GAMES!    3441    8889  40067
# 4  Air superiority: achieved.\n8,000+ targets: el...    4399    3793  16922
# 5  "If the Radical Left Democrats don’t immediate...    5421   10961  35063
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors="coerce")

# %%
df['time'] = df['date'].dt.time
df['date'] = df['date'].dt.date

# %%
df.head()
# Out:
#          date    username                                               text  \
# 0  2026-03-21  WhiteHouse                                                NaN
# 1  2026-03-21  WhiteHouse  The United States and Japan continued to stren...
# 2  2026-03-21  WhiteHouse                    NO MORE WAITING, NO MORE GAMES!
# 3  2026-03-21  WhiteHouse                    NO MORE WAITING, NO MORE GAMES!
# 4  2026-03-21  WhiteHouse  Air superiority: achieved.\n8,000+ targets: el...
#
#   replies reposts  likes bookmarks    views      time
# 0     156     255    907        31   154980  18:57:57
# 1    1129    2992  13264       375   271102  18:57:41
# 2   11063   11699  52704      1836  6345973  17:52:23
# 3    3441    8889  40067       813  2966036  17:51:59
# 4    4399    3793  16922       418   648078  17:17:42
