# %%
import pandas as pd

# %%
df = pd.read_csv("../../data_fetching/truthSocial/trump_tweets.csv")
df.head()
# Out:
#                                       url         username   DateKey  TimeKey  \
# 0  https://trumpstruth.org/statuses/37757  realDonaldTrump  20260414   140900
# 1  https://trumpstruth.org/statuses/37756  realDonaldTrump  20260414   135100
# 2  https://trumpstruth.org/statuses/37755  realDonaldTrump  20260414   134900
# 3  https://trumpstruth.org/statuses/37753  realDonaldTrump  20260414    52400
# 4  https://trumpstruth.org/statuses/37754  realDonaldTrump  20260414    52300
#
#                                                 Text  deleted
# 0  Bruce Blakeman, the highly respected and very ...        0
# 1  Alan, one of the greats, should do it! Preside...        0
# 2  Biden administration weaponized law to infring...        0
# 3  Georgia lawmaker wants Fani Willis to answer q...        0
# 4  Alan Dershowitz: Trump could move to expunge 2...        0

# %%
print(df.info())
print(len(df))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30851 entries, 0 to 30850
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       30851 non-null  str
#  1   username  30851 non-null  str
#  2   DateKey   30851 non-null  int64
#  3   TimeKey   30851 non-null  int64
#  4   Text      25542 non-null  str
#  5   deleted   30851 non-null  int64
# dtypes: int64(3), str(3)
# memory usage: 1.4 MB
# None
# 30851

# %% [markdown]
# ### removing deleted tweets (deleted = 1)

# %%
df = df[df['deleted'] == 0]

# %%
len(df)
# Out:
# 30263

# %% [markdown]
# #### we hebben tweets die geen text hebben, deze verwijderen we ook

# %%
df = df[df['Text'].notna()]
print(len(df))
# Out:
# 24983

# %%
df.head()
# Out:
#                                       url         username   DateKey  TimeKey  \
# 0  https://trumpstruth.org/statuses/37757  realDonaldTrump  20260414   140900
# 1  https://trumpstruth.org/statuses/37756  realDonaldTrump  20260414   135100
# 2  https://trumpstruth.org/statuses/37755  realDonaldTrump  20260414   134900
# 3  https://trumpstruth.org/statuses/37753  realDonaldTrump  20260414    52400
# 4  https://trumpstruth.org/statuses/37754  realDonaldTrump  20260414    52300
#
#                                                 Text  deleted
# 0  Bruce Blakeman, the highly respected and very ...        0
# 1  Alan, one of the greats, should do it! Preside...        0
# 2  Biden administration weaponized law to infring...        0
# 3  Georgia lawmaker wants Fani Willis to answer q...        0
# 4  Alan Dershowitz: Trump could move to expunge 2...        0

# %%
df.to_csv("../../processed/trump_tweets.csv", index=False)
